# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import timeit
# %matplotlib inline

# %%
def MC_cir(r, N):
    fig,ax = plt.subplots(1,2)
    fig.set_size_inches(6,3)
    
    ax[0].set(xlim=(-r,r), ylim=(-r,r), xlabel='x', ylabel='y')
    n = 1
    C = 0
    S = 0
    while n <= N:
        x = random.uniform(0,r)
        y = random.uniform(0,r)
        S+=1
        if (x**2 + y**2) <= (r**2):
            ax[0].scatter(x,y, color='blue', s = 2)
            
            C+=1
        else:
            ax[0].scatter(x,y, color='red', s = 2)
        n_pi = 4 * (C/S)
        n_err = n_pi - np.pi
        ax[1].scatter(n,n_err, s=2)
       
        n+=1
    return n_pi, n_err

# %%
MC_cir(1,10000)
# Out:
# (3.152, 0.010407346410207019)

# %%
MC_cir(1,10000)
# Out:
# (3.1512, 0.009607346410206663)
